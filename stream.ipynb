# %%
# ------------------------ REFERENCES ------------------------ #
# "NLP Tutorial 10 - Real Time Twitter Sentiment Analysis | Donald Trump vs Warren Twitter Sentiment". YouTube, uploaded by KGP Talkie, Nov 2, 2019, URL: https://youtu.be/gUFDtuz73gI

# %% [markdown]
# # Authentication

# %%
consumer_key = '<your consumer key>'
consumer_secret = '<your consumer secret>'
access_token = '<your access token>'
access_token_secret = '<your access token secret>'
bearer_token = '<your bearer token>'

# %%
import tweepy

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
api = tweepy.API(auth)

# %%
import pandas as pd

# UPDATE POSITIVE/NEGATIVE VALUES ON START OF PROGRAM FROM DB
Province_indexes = {'KPK':0,'FATA':1,'ISLAMABAD':2,'PUNJAB':3,'SINDH':4,'BALOCHISTAN':5}
df = pd.read_csv('IK_tweets_provincial_stats.csv')
print(df)

# Provinces = ['KPK','FATA','ISLAMABAD','PUNJAB','SINDH','BALOCHISTAN']
# Positive = {'KPK':0,'FATA':0,'ISLAMABAD':0,'PUNJAB':0,'SINDH':0,'BALOCHISTAN':0}
# Negative = {'KPK':0,'FATA':0,'ISLAMABAD':0,'PUNJAB':0,'SINDH':0,'BALOCHISTAN':0}
# Data = {'Province': Provinces, 'Positive': list(Positive.values()), 'Negative': list(Negative.values())}
# df = pd.DataFrame(Data, columns= ['Province', 'Positive', 'Negative'])
# Out:
#       Province  Positive  Negative  Neutral
# 0          KPK       130       101      186
# 1         FATA        21        18       29
# 2    ISLAMABAD         8         5        9
# 3       PUNJAB       455       350      715
# 4        SINDH       203       161      326
# 5  BALOCHISTAN        43        28       80

# %% [markdown]
# # Sentiment analysis functions

# %%
from textblob import TextBlob

def get_sentiment_textBlob(text, province):
    # create TextBlob object of passed tweet text
    analysis = TextBlob(text)
    # set sentiment
    sentiment = ''
    subjectivity = ''
    if analysis.sentiment.polarity > 0:
        sentiment = 'positive 🙂'
        df['Positive'][Province_indexes[province]] += 1
    elif analysis.sentiment.polarity == 0:
        sentiment = 'neutral 😶'
        df['Neutral'][Province_indexes[province]] += 1
    else:
        sentiment = 'negative 😠'
        df['Negative'][Province_indexes[province]] += 1

    if analysis.sentiment.subjectivity > 0.5:
        subjectivity = '🗣 opinion'
    elif analysis.sentiment.polarity < 0.5:
        subjectivity = '📊 factual '
    else:
        subjectivity = '😶 neutral'
    
    return sentiment + ' : ' + subjectivity

# %%
print('🙂')
# Out:
# 🙂

# %% [markdown]
# # Location

# %%
# def get_location():
#     return random.choice(['KPK','FATA','ISLAMABAD','PUNJAB','SINDH','BALOCHISTAN'])

def get_location():
    import random
    return (random.choices(df['Province'], weights=(30508920, 4993044, 2003368, 109989655, 47854510, 12335129), k=1))[0]

# %% [markdown]
# # Streaming helper functions

# %%
# SOURCE: 'Twitter-API-v2-sample-code'. GitHub, uploaded by EthanJWright et al. 28 Aug, 2020. URL: 'https://github.com/twitterdev/Twitter-API-v2-sample-code/blob/master/Filtered-Stream/filtered_stream.py' [Accessed: 17 June 2021]

import requests
import os
import json

def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers


def get_rules(headers, bearer_token):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream/rules", headers=headers
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot get rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    return response.json()


def delete_all_rules(headers, bearer_token, rules):
    if rules is None or "data" not in rules:
        return None

    ids = list(map(lambda rule: rule["id"], rules["data"]))
    payload = {"delete": {"ids": ids}}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot delete rules (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    print(json.dumps(response.json()))



def set_rules(headers, delete, bearer_token):
    # You can adjust the rules if needed
    sample_rules = [
        # {"value": "politics", "tag": "Imran Khan"},
        {"value": "Imran Khan", "tag": "politics", "keyword": "Imran Khan", "lang": "en"},
        # {"value": "politics", "tag": "#ImranKhan"},                       # THIS DOESN'T WORK
        # {"value": "dog has:images", "tag": "dog pictures"},
        # {"value": "cat has:images -grumpy", "tag": "cat pictures"},
    ]
    payload = {"add": sample_rules}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload,
    )
    if response.status_code != 201:
        raise Exception(
            "Cannot add rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))

# %% [markdown]
# # PREPROCESSING

# %%
import re
import nltk
import emoji
from nltk.stem import WordNetLemmatizer
from nltk.corpus import words

words = set(words.words())
def get_tweet_text(tweet_details):
    # REGEX SOURCES: 
    # 'Extract string after colon or parenthesis with regex in python', question on Stackoverflow, answered by Gustav Rasmussen, 10 July 2020, URL: https://stackoverflow.com/questions/62831803/extract-string-after-colon-or-parenthesis-with-regex-in-python, [Accessed: 17 June 2021]
    # 'RegEx: Grabbing values between quotation marks', question on Stackoverflow answered by Adam, 5 October 2008, URL: https://stackoverflow.com/questions/171480/regex-grabbing-values-between-quotation-marks, [Accessed: 17 June 2021]
    # 'Regex to get words after matching string', question on Stackoverflow answered by Himanshu Chauhan, 20 September 2016, URL: https://stackoverflow.com/questions/19193251/regex-to-get-the-words-after-matching-string, [Accessed: 17 June 2021]
    regex = re.compile( r"(?<=\"text\":\s).*([\"\"])(?:(?=(\\?)).)*?", re.I )
    return re.search(regex, tweet_details).group(0)

# 'Cleaning Twitter data pandas python', question on Stackoverflow answered by Celius Stingher, 6 November 2020, URL: https://stackoverflow.com/questions/64719706/cleaning-twitter-data-pandas-python, [Accessed: 18 June 2021]
# 'How to get rid of punctuation using NLTK tokenizer?', question on Stackoverflow answered by rmalouf, 21 March 2013, URL: https://stackoverflow.com/questions/15547409/how-to-get-rid-of-punctuation-using-nltk-tokenizer, [Accessed: 18 June 2021]
def cleaner(tweet):
    tweet= re.sub(r"\\n","",tweet)                                      # Removing \n
    tweet= re.sub(r"\\u....","",tweet)                                  # Removing unicode
    tweet= re.sub(r"RT[\s]+","",tweet)                                  # Removing RT
    tweet = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", tweet)    # Remove http links and mentions
    tweet = " ".join(tweet.split())
    tweet = ''.join(c for c in tweet if c not in emoji.UNICODE_EMOJI)   # Remove Emojis
    tweet = tweet.replace("#", "").replace("_", " ")                    # Remove hashtag sign but keep the text
    tweet = tweet.lower()
    tokenizer = RegexpTokenizer(r'\w+')                               # |
    tweet = " ".join(tokenizer.tokenize(tweet))                       # Remove punctuation marks

    return tweet
    
    # tweet = " ".join(w for w in nltk.wordpunct_tokenize(tweet) \
    #      if w.lower() in words or not w.isalpha())
    # for w in nltk.wordpunct_tokenize(tweet)

def half_cleaner(tweet):
    tweet= re.sub(r"\\n","",tweet)                                      # Removing \n
    tweet= re.sub(r"\\u....","",tweet)                                  # Removing unicode
    return tweet

def lemmatize(text):
    new_text = []
    words = nltk.wordpunct_tokenize(text)
    lemmatizer = WordNetLemmatizer()
    for word in words:
        new_text.append(lemmatizer.lemmatize(word))

    new_text = " ".join(new_text)
    return new_text

# %% [markdown]
# # Main streaming function

# %%
import csv
import random
import time
from nltk.tokenize import RegexpTokenizer

field_names = ['tweet', 'location', 'sentiment']

def get_stream(headers, set, bearer_token):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream", headers=headers, stream=True,
    )
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Cannot get stream (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    tweetNo = 0
    # Below line gives an error sometimes. This is a twitter API issue being faced by multiple developers and is currently being worked on. SOURCE: https://twittercommunity.com/t/requests-exceptions-chunkedencodingerror/150530 [Accessed: 18 June 2021]
    for response_line in response.iter_lines():
        if response_line:
            tweetNo += 1
            json_response = json.loads(response_line)
            tempTweet = json.dumps(json_response, indent=4, sort_keys=True)

            # --VARIABLES--
            tweet = {}                                  # of the form {'location': ,'tweet':, 'sentiment':}
            tweet['location'] = get_location()
            text = get_tweet_text(tempTweet)
            cleaned_text = cleaner(text)
            lemmatized_cleaned_text = lemmatize(cleaned_text)
            sentiment = get_sentiment_textBlob(cleaned_text, tweet['location'])
            tweet['tweet'] = lemmatized_cleaned_text
            tweet['sentiment'] = sentiment
            # --PRINT--
            print('Tweet ', tweetNo, ':\n', tempTweet)
            print('TWEET TEXT: ', text)
            print('CLEANED TEXT: ', cleaned_text)
            print('CLEANED AND LEMMATIZED: ', lemmatized_cleaned_text)
            print('SENTIMENT: ', sentiment)
            print('LOCATION: ', tweet['location'])
            # --SAVE--            
            df.to_csv('IK_tweets_provincial_stats.csv', index = False, header=True)
            f_obj = open('tweet.txt', 'w')
            # sentiment = ''.join(c for c in sentiment if c not in emoji.UNICODE_EMOJI)   # Remove Emojis
            sentiment = re.sub(r"..:..", ' | ', sentiment)
            half_cleaned_text = half_cleaner(text)
            f_obj.write(sentiment+'\n'+half_cleaned_text)
            f_obj.close()
            # with open('IK_tweets.csv', 'a') as csv_file:
            #     csv_writer = csv.DictWriter(csv_file, fieldnames = field_names)
            #     csv_writer.writerow(tweet)
            #     print('Tweet written to CSV...')
    return

# %% [markdown]
# # STREAM!

# %%
data = api.rate_limit_status()

print (data['resources']['statuses']['/statuses/home_timeline'])
print (data['resources']['users']['/users/lookup'])
# Out:
# {'limit': 15, 'remaining': 15, 'reset': 1624296800}
# {'limit': 900, 'remaining': 900, 'reset': 1624296800}

# %%
def main():
    bearer_token = '<your bearer token>'
    headers = create_headers(bearer_token)
    rules = get_rules(headers, bearer_token)
    delete = delete_all_rules(headers, bearer_token, rules)
    set = set_rules(headers, delete, bearer_token)
    get_stream(headers, set, bearer_token)

if __name__ == "__main__":
    main()
# Out:
# {"data": [{"id": "1406961359074385923", "value": "Imran Khan", "tag": "politics"}], "meta": {"sent": "2021-06-21T17:18:22.248Z"}}
# {"meta": {"sent": "2021-06-21T17:18:23.256Z", "summary": {"deleted": 1, "not_deleted": 0}}}
# {"data": [{"value": "Imran Khan", "tag": "politics", "id": "1407025118488895500"}], "meta": {"sent": "2021-06-21T17:18:24.200Z", "summary": {"created": 1, "not_created": 0, "valid": 1, "invalid": 0}}}
# 200
# <ipython-input-7-63ea1eee0b1d>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Negative'][Province_indexes[province]] += 1
# Tweet  1 :
#  {
#     "data": {
#         "id": "1407025093293842436",
#         "text": "RT @AdnanhussainAD: \"If a woman is wearing v few clothes, it will have an impact on the men, unless they're robots\" PM Imran Khan https://t\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @AdnanhussainAD: \"If a woman is wearing v few clothes, it will have an impact on the men, unless they're robots\" PM Imran Khan https://t\u2026"
# CLEANED TEXT:  if a woman is wearing v few clothes it will have an impact on the men unless they re robots pm imran khan
# CLEANED AND LEMMATIZED:  if a woman is wearing v few clothes it will have an impact on the men unless they re robot pm imran khan
# SENTIMENT:  negative 😠 : 📊 factual
# LOCATION:  BALOCHISTAN
# <ipython-input-7-63ea1eee0b1d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Positive'][Province_indexes[province]] += 1
# Tweet  2 :
#  {
#     "data": {
#         "id": "1407025118493151232",
#         "text": "RT @ShahabSpeaks: 3 unforgettable lines \u2b07\ufe0f\n\nImran Khan: Absolutely Not \nAsif Ghafoor: We will surprise you\nShah Mehmood: Deep pockets"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @ShahabSpeaks: 3 unforgettable lines \u2b07\ufe0f\n\nImran Khan: Absolutely Not \nAsif Ghafoor: We will surprise you\nShah Mehmood: Deep pockets"
# CLEANED TEXT:  3 unforgettable lines imran khan absolutely not asif ghafoor we will surprise youshah mehmood deep pockets
# CLEANED AND LEMMATIZED:  3 unforgettable line imran khan absolutely not asif ghafoor we will surprise youshah mehmood deep pocket
# SENTIMENT:  positive 🙂 : 🗣 opinion
# LOCATION:  PUNJAB
# <ipython-input-7-63ea1eee0b1d>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Neutral'][Province_indexes[province]] += 1
# Tweet  3 :
#  {
#     "data": {
#         "id": "1407025132363735041",
#         "text": "RT @ashoswai: Why does the world expect Imran Khan to raise the Uyghur Muslim issue, but no one asks this to India? What has stopped India\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @ashoswai: Why does the world expect Imran Khan to raise the Uyghur Muslim issue, but no one asks this to India? What has stopped India\u2026"
# CLEANED TEXT:  why does the world expect imran khan to raise the uyghur muslim issue but no one asks this to india what has stopped india
# CLEANED AND LEMMATIZED:  why doe the world expect imran khan to raise the uyghur muslim issue but no one asks this to india what ha stopped india
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  PUNJAB
# Tweet  4 :
#  {
#     "data": {
#         "id": "1407025132464390151",
#         "text": "RT @akkhan81: Imran Khan is always decrying Islamophobia in the West but makes statements about Pakistani culture and Islam that reinforce\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @akkhan81: Imran Khan is always decrying Islamophobia in the West but makes statements about Pakistani culture and Islam that reinforce\u2026"
# CLEANED TEXT:  imran khan is always decrying islamophobia in the west but makes statements about pakistani culture and islam that reinforce
# CLEANED AND LEMMATIZED:  imran khan is always decrying islamophobia in the west but make statement about pakistani culture and islam that reinforce
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  KPK
# Tweet  5 :
#  {
#     "data": {
#         "id": "1407025138248290308",
#         "text": "RT @RifatEmil: Most wickets in T20s: \n\nDJ Bravo 517\nImran Tahir 394*\nSP Narine 393\nSL Malinga 390 \nShakib Al Hasan 370 \nRashid Khan 370\n\n#I\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @RifatEmil: Most wickets in T20s: \n\nDJ Bravo 517\nImran Tahir 394*\nSP Narine 393\nSL Malinga 390 \nShakib Al Hasan 370 \nRashid Khan 370\n\n#I\u2026"
# CLEANED TEXT:  most wickets in t20s dj bravo 517imran tahir 394 sp narine 393sl malinga 390 shakib al hasan 370 rashid khan 370i
# CLEANED AND LEMMATIZED:  most wicket in t20s dj bravo 517imran tahir 394 sp narine 393sl malinga 390 shakib al hasan 370 rashid khan 370i
# SENTIMENT:  positive 🙂 : 😶 neutral
# LOCATION:  PUNJAB
# Tweet  6 :
#  {
#     "data": {
#         "id": "1407025139800100869",
#         "text": "RT @MeghUpdates: If a Woman wears very Few Clothes, it will have an impact on Men. If you Raise Temptations, Where will Men vent out : Pak\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @MeghUpdates: If a Woman wears very Few Clothes, it will have an impact on Men. If you Raise Temptations, Where will Men vent out : Pak\u2026"
# CLEANED TEXT:  if a woman wears very few clothes it will have an impact on men if you raise temptations where will men vent out pak
# CLEANED AND LEMMATIZED:  if a woman wear very few clothes it will have an impact on men if you raise temptation where will men vent out pak
# SENTIMENT:  negative 😠 : 📊 factual
# LOCATION:  SINDH
# Tweet  7 :
#  {
#     "data": {
#         "id": "1407025141612269576",
#         "text": "@hishamelahi Imran khan hmesha islam ki bat krta he aur ap log hmsha usk against hoty hen ..Lekin agr ap b wohi bat kr rahy hen jo khan kr raha to uska sath den ..."
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "@hishamelahi Imran khan hmesha islam ki bat krta he aur ap log hmsha usk against hoty hen ..Lekin agr ap b wohi bat kr rahy hen jo khan kr raha to uska sath den ..."
# CLEANED TEXT:  imran khan hmesha islam ki bat krta he aur ap log hmsha usk against hoty hen lekin agr ap b wohi bat kr rahy hen jo khan kr raha to uska sath den
# CLEANED AND LEMMATIZED:  imran khan hmesha islam ki bat krta he aur ap log hmsha usk against hoty hen lekin agr ap b wohi bat kr rahy hen jo khan kr raha to uska sath den
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  SINDH
# Tweet  8 :
#  {
#     "data": {
#         "id": "1407025147765219334",
#         "text": "RT @PTIOfficialUSA: Anchorperson: You were accused of rape victim blaming, how do you respond to that?\n\nPM Imran Khan: It is #SuchNonsense\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @PTIOfficialUSA: Anchorperson: You were accused of rape victim blaming, how do you respond to that?\n\nPM Imran Khan: It is #SuchNonsense\u2026"
# CLEANED TEXT:  anchorperson you were accused of rape victim blaming how do you respond to that pm imran khan it is suchnonsense
# CLEANED AND LEMMATIZED:  anchorperson you were accused of rape victim blaming how do you respond to that pm imran khan it is suchnonsense
# SENTIMENT:  negative 😠 : 📊 factual
# LOCATION:  KPK
# Tweet  9 :
#  {
#     "data": {
#         "id": "1407025147941359622",
#         "text": "The playboy talking nonsense https://t.co/TTLS20OmqM"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  

#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "Imran Khan ne sirf eska English tarjma kiya hai. Or liberals ko aag lagi hoyi hai. https://t.co/ZVfX4sR013"
# CLEANED TEXT:  imran khan ne sirf eska english tarjma kiya hai or liberals ko aag lagi hoyi hai
# CLEANED AND LEMMATIZED:  imran khan ne sirf eska english tarjma kiya hai or liberal ko aag lagi hoyi hai
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  SINDH
# Tweet  16 :
#  {
#     "data": {
#         "id": "1407025188643000324",
#         "text": "RT @Kan__Fatima: The veil is not ordered by Imran Khan but by the Holy Quran. \n#Muslim \n#KhanWonTheHearts"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @Kan__Fatima: The veil is not ordered by Imran Khan but by the Holy Quran. \n#Muslim \n#KhanWonTheHearts"
# CLEANED TEXT:  the veil is not ordered by imran khan but by the holy quran muslim khanwonthehearts
# CLEANED AND LEMMATIZED:  the veil is not ordered by imran khan but by the holy quran muslim khanwonthehearts
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  SINDH
# Tweet  17 :
#  {
#     "data": {
#         "id": "1407025206598766592",
#         "text": "RT @jaaztime: #\u0628\u0627\u0643\u0633\u062a\u0627\u0646: \n\n\u0627\u0646\u062a\u0642\u0627\u062f\u0627\u062a \u0644\u0640 #\u0639\u0645\u0631\u0627\u0646_\u062e\u0627\u0646 \n\u0644\u0625\u0644\u0642\u0627\u0626\u0647 \u0628\u0627\u0644\u0644\u0648\u0645 \u0639\u0644\u0649 \u0627\u0644\u0646\u0633\u0627\u0621 \n\u0641\u064a #\u0627\u0644\u0639\u0646\u0641_\u0627\u0644\u062c\u0646\u0633\u064a \n\n\u0648\u0642\u0627\u0644 #\u0631\u0626\u064a\u0633_\u0627\u0644\u0648\u0632\u0631\u0627\u0621\n\u0641\u064a \u0645\u0642\u0627\u0628\u0644\u0629 \u0645\u0639  (Axios HBO\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @jaaztime: #\u0628\u0627\u0643\u0633\u062a\u0627\u0646: \n\n\u0627\u0646\u062a\u0642\u0627\u062f\u0627\u062a \u0644\u0640 #\u0639\u0645\u0631\u0627\u0646_\u062e\u0627\u0646 \n\u0644\u0625\u0644\u0642\u0627\u0626\u0647 \u0628\u0627\u0644\u0644\u0648\u0645 \u0639\u0644\u0649 \u0627\u0644\u0646\u0633\u0627\u0621 \n\u0641\u064a #\u0627\u0644\u0639\u0646\u0641_\u0627\u0644\u062c\u0646\u0633\u064a \n\n\u0648\u0642\u0627\u0644 #\u0631\u0626\u064a\u0633_\u0627\u0644\u0648\u0632\u0631\u0627\u0621\n\u0641\u064a \u0645\u0642\u0627\u0628\u0644\u0629 \u0645\u0639  (Axios HBO\u2026"
# CLEANED TEXT:  axios hbo
# CLEANED AND LEMMATIZED:  axios hbo
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  SINDH
# Tweet  18 :
#  {
#     "data": {
#         "id": "1407025219055853569",
#         "text": "RT @ammaralijan: Only 3 days after a child was raped by a cleric, Imran Khan chooses to blame \"few clothes\" worn by women for rape culture.\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @ammaralijan: Only 3 days after a child was raped by a cleric, Imran Khan chooses to blame \"few clothes\" worn by women for rape culture.\u2026"
# CLEANED TEXT:  only 3 days after a child was raped by a cleric imran khan chooses to blame few clothes worn by women for rape culture
# CLEANED AND LEMMATIZED:  only 3 day after a child wa raped by a cleric imran khan chooses to blame few clothes worn by woman for rape culture
# SENTIMENT:  negative 😠 : 🗣 opinion
# LOCATION:  PUNJAB
# Tweet  19 :
#  {
#     "data": {
#         "id": "1407025221362663425",
#         "text": "RT @OpIndia_com: \u2018Degenerate\u2019 Imran Khan does it again, blames women for rising sexual violence in Pakistan\nhttps://t.co/EA3YzideHr"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @OpIndia_com: \u2018Degenerate\u2019 Imran Khan does it again, blames women for rising sexual violence in Pakistan\nhttps://t.co/EA3YzideHr"
# CLEANED TEXT:  degenerate imran khan does it again blames women for rising sexual violence in pakistan
# CLEANED AND LEMMATIZED:  degenerate imran khan doe it again blame woman for rising sexual violence in pakistan
# SENTIMENT:  positive 🙂 : 🗣 opinion
# LOCATION:  PUNJAB
# Tweet  20 :
#  {
#     "data": {
#         "id": "1407025224055353346",
#         "text": "RT @manopatano: As for the Uighurs issue, Imran Khan has repeatedly said that we conduct our discussions with Chinese behind closed doors.\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @manopatano: As for the Uighurs issue, Imran Khan has repeatedly said that we conduct our discussions with Chinese behind closed doors.\u2026"
# CLEANED TEXT:  as for the uighurs issue imran khan has repeatedly said that we conduct our discussions with chinese behind closed doors
# CLEANED AND LEMMATIZED:  a for the uighur issue imran khan ha repeatedly said that we conduct our discussion with chinese behind closed door
# SENTIMENT:  negative 😠 : 📊 factual
# LOCATION:  KPK
# Tweet  21 :
#  {
#     "data": {
#         "id": "1407025235522641927",
#         "text": "@Iam_Mian Agree with him."
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "@Iam_Mian Agree with him."
# CLEANED TEXT:  agree with him
# CLEANED AND LEMMATIZED:  agree with him
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  KPK
# Tweet  22 :
#  {
#     "data": {
#         "id": "1407025238639058946",
#         "text": "if the came wrapped in parcel paper they would still f==k them the filthy bastards https://t.co/Z6luCEySY7"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "if the came wrapped in parcel paper they would still f==k them the filthy bastards https://t.co/Z6luCEySY7"
# CLEANED TEXT:  if the came wrapped in parcel paper they would still f k them the filthy bastards
# CLEANED AND LEMMATIZED:  if the came wrapped in parcel paper they would still f k them the filthy bastard
# SENTIMENT:  negative 😠 : 🗣 opinion
# LOCATION:  SINDH
# Tweet  23 :
#  {
#     "data": {
#         "id": "1407025243219234825",
#         "text": "@nailainayat Deep Space  Mentality \ud83d\udc7d"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "@nailainayat Deep Space  Mentality \ud83d\udc7d"
# CLEANED TEXT:  deep space mentality
# CLEANED AND LEMMATIZED:  deep space mentality
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  SINDH
# Tweet  24 :
#  {
#     "data": {
#         "id": "1407025257593061381",
#         "text": "RT @AdnanhussainAD: \"If a woman is wearing v few clothes, it will have an impact on the men, unless they're robots\" PM Imran Khan https://t\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  FATA
# Tweet  35 :
#  {
#     "data": {
#         "id": "1407025287855017984",
#         "text": "RT @Burhan_Saeed10: According to liberals, if Imran Khan is a rape apologist, do remember that you and your liberal cult were against the c\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @Burhan_Saeed10: According to liberals, if Imran Khan is a rape apologist, do remember that you and your liberal cult were against the c\u2026"
# CLEANED TEXT:  according to liberals if imran khan is a rape apologist do remember that you and your liberal cult were against the c
# CLEANED AND LEMMATIZED:  according to liberal if imran khan is a rape apologist do remember that you and your liberal cult were against the c
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  PUNJAB
# Tweet  36 :
#  {
#     "data": {
#         "id": "1407025286965776390",
#         "text": "RT @Big__Bro6: #\u0628\u06d2\u062d\u06cc\u0627\u0626\u06cc_\u0645\u06a9\u0627\u0624_\u0645\u0639\u0627\u0634\u0631\u06c1_\u0628\u0686\u0627\u0624\nWhen American journalist Jonathan  asked Imran Khan about the incidents of rape and sexual crimes\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @Big__Bro6: #\u0628\u06d2\u062d\u06cc\u0627\u0626\u06cc_\u0645\u06a9\u0627\u0624_\u0645\u0639\u0627\u0634\u0631\u06c1_\u0628\u0686\u0627\u0624\nWhen American journalist Jonathan  asked Imran Khan about the incidents of rape and sexual crimes\u2026"
# CLEANED TEXT:  when american journalist jonathan asked imran khan about the incidents of rape and sexual crimes
# CLEANED AND LEMMATIZED:  when american journalist jonathan asked imran khan about the incident of rape and sexual crime
# SENTIMENT:  positive 🙂 : 📊 factual
# LOCATION:  BALOCHISTAN
# Tweet  37 :
#  {
#     "data": {
#         "id": "1407025294892945412",
#         "text": "RT @ashoswai: Why does the world expect Imran Khan to raise the Uyghur Muslim issue, but no one asks this to India? What has stopped India\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @ashoswai: Why does the world expect Imran Khan to raise the Uyghur Muslim issue, but no one asks this to India? What has stopped India\u2026"
# CLEANED TEXT:  why does the world expect imran khan to raise the uyghur muslim issue but no one asks this to india what has stopped india
# CLEANED AND LEMMATIZED:  why doe the world expect imran khan to raise the uyghur muslim issue but no one asks this to india what ha stopped india
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  BALOCHISTAN
# Tweet  38 :
#  {
#     "data": {
#         "id": "1407025293752246277",
#         "text": "RT @DominicFarrell: Always the woman\u2019s fault &gt; Imran Khan sparks fury by blaming 'temptation' for sexual violence. https://t.co/S0MfE2Spgt"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @DominicFarrell: Always the woman\u2019s fault &gt; Imran Khan sparks fury by blaming 'temptation' for sexual violence. https://t.co/S0MfE2Spgt"
# CLEANED TEXT:  always the womans fault gt imran khan sparks fury by blaming temptation for sexual violence
# CLEANED AND LEMMATIZED:  always the woman fault gt imran khan spark fury by blaming temptation for sexual violence
# SENTIMENT:  positive 🙂 : 🗣 opinion
# LOCATION:  PUNJAB
# Tweet  39 :
#  {
#     "data": {
#         "id": "1407025297539616774",
#         "text": "Dude literally said men are trash and still got flak for it. https://t.co/Rlk9DdeBhn"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "Dude literally said men are trash and still got flak for it. https://t.co/Rlk9DdeBhn"
# CLEANED TEXT:  dude literally said men are trash and still got flak for it
# CLEANED AND LEMMATIZED:  dude literally said men are trash and still got flak for it
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  SINDH
# Tweet  40 :
#  {
#     "data": {
#         "id": "1407025311989092352",
#         "text": "RT @axios: .@jonathanvswan presses Pakistan Prime Minister Imran Khan on why he\u2019s outspoken against Islamophobia in the West but silent abo\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @axios: .@jonathanvswan presses Pakistan Prime Minister Imran Khan on why he\u2019s outspoken against Islamophobia in the West but silent abo\u2026"
# CLEANED TEXT:  presses pakistan prime minister imran khan on why hes outspoken against islamophobia in the west but silent abo
# CLEANED AND LEMMATIZED:  press pakistan prime minister imran khan on why he outspoken against islamophobia in the west but silent abo
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  PUNJAB
# Tweet  41 :
#  {
#     "data": {
#         "id": "1407025313855332353",
#         "text": "RT @OpIndia_com: \u2018Degenerate\u2019 Imran Khan does it again, blames women for rising sexual violence in Pakistan\nhttps://t.co/EA3YzideHr"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @OpIndia_com: \u2018Degenerate\u2019 Imran Khan does it again, blames women for rising sexual violence in Pakistan\nhttps://t.co/EA3YzideHr"
# CLEANED TEXT:  degenerate imran khan does it again blames women for rising sexual violence in pakistan
# CLEANED AND LEMMATIZED:  degenerate imran khan doe it again blame woman for rising sexual violence in pakistan
# SENTIMENT:  positive 🙂 : 🗣 opinion
# LOCATION:  KPK
# Tweet  42 :
#  {
#     "data": {
#         "id": "1407025312626397191",
#         "text": "RT @axios: .@jonathanvswan presses Pakistan Prime Minister Imran Khan on why he\u2019s outspoken against Islamophobia in the West but silent abo\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @axios: .@jonathanvswan presses Pakistan Prime Minister Imran Khan on why he\u2019s outspoken against Islamophobia in the West but silent abo\u2026"
# CLEANED TEXT:  presses pakistan prime minister imran khan on why hes outspoken against islamophobia in the west but silent abo
# CLEANED AND LEMMATIZED:  press pakistan prime minister imran khan on why he outspoken against islamophobia in the west but silent abo
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  SINDH
# Tweet  43 :
#  {
#     "data": {
#         "id": "1407025315239448576",
#         "text": "RT @Ihtieshamkhan: #\u0628\u06d2\u062d\u06cc\u0627\u0626\u06cc_\u0645\u06a9\u0627\u0624_\u0645\u0639\u0627\u0634\u0631\u06c1_\u0628\u0686\u0627\u0624\nProud Statement by PM Imran Khan https://t.co/jam1h2BmNJ"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @Ihtieshamkhan: #\u0628\u06d2\u062d\u06cc\u0627\u0626\u06cc_\u0645\u06a9\u0627\u0624_\u0645\u0639\u0627\u0634\u0631\u06c1_\u0628\u0686\u0627\u0624\nProud Statement by PM Imran Khan https://t.co/jam1h2BmNJ"
# CLEANED TEXT:  proud statement by pm imran khan
# CLEANED AND LEMMATIZED:  proud statement by pm imran khan
# SENTIMENT:  positive 🙂 : 🗣 opinion
# LOCATION:  PUNJAB
# Tweet  44 :
#  {
#     "data": {
#         "id": "1407025321950416896",
#         "text": "@DailyScoopTV1 @IhsanTipu Every single officer is corrupt.."
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "@DailyScoopTV1 @IhsanTipu Every single officer is corrupt.."
# CLEANED TEXT:  every single officer is corrupt
# CLEANED AND LEMMATIZED:  every single officer is corrupt
# SENTIMENT:  negative 😠 : 🗣 opinion
# LOCATION:  PUNJAB
# Tweet  45 :
#  {
#     "data": {
#         "id": "1407025322730606594",
#         "text": "Disgusting https://t.co/XiBKW2dtTR"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "Disgusting https://t.co/XiBKW2dtTR"
# CLEANED TEXT:  disgusting
# CLEANED AND LEMMATIZED:  disgusting
# SENTIMENT:  negative 😠 : 🗣 opinion
# LOCATION:  PUNJAB
# Tweet  46 :
#  {
#     "data": {
#         "id": "1407025329324109831",
#         "text": "RT @Scrivenshaft_: Imran khan has extremely problematic views about rape culture and he will deserve every bit of ridicule and scorn he wil\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @Scrivenshaft_: Imran khan has extremely problematic views about rape culture and he will deserve every bit of ridicule and scorn he wil\u2026"
# CLEANED TEXT:  imran khan has extremely problematic views about rape culture and he will deserve every bit of ridicule and scorn he wil
# CLEANED AND LEMMATIZED:  imran khan ha extremely problematic view about rape culture and he will deserve every bit of ridicule and scorn he wil
# SENTIMENT:  negative 😠 : 🗣 opinion
# LOCATION:  PUNJAB
# Tweet  47 :
#  {
#     "data": {
#         "id": "1407025333325512708",
#         "text": "@FarhanRai02 Actually the God of the Quran is sexist according to your mind set."
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "@FarhanRai02 Actually the God of the Quran is sexist according to your mind set."
# CLEANED TEXT:  actually the god of the quran is sexist according to your mind set
# CLEANED AND LEMMATIZED:  actually the god of the quran is sexist according to your mind set
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  SINDH
# Tweet  48 :
#  {
#     "data": {
#         "id": "1407025341785423883",
#         "text": "RT @KhubaibMkf: PM Imran Khan highlighted that Islamophobia has increased in Europe after 9/11 and urged international efforts to counter t\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @KhubaibMkf: PM Imran Khan highlighted that Islamophobia has increased in Europe after 9/11 and urged international efforts to counter t\u2026"
# CLEANED TEXT:  pm imran khan highlighted that islamophobia has increased in europe after 9 11 and urged international efforts to counter t
# CLEANED AND LEMMATIZED:  pm imran khan highlighted that islamophobia ha increased in europe after 9 11 and urged international effort to counter t
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  PUNJAB
# Tweet  49 :
#  {
#     "data": {
#         "id": "1407025348508733441",
#         "text": "RT @Heenaishappy: Prime minister Imran Khan says \u201c#China is the greatest friend of Pakistan\u201d that's why #Pakistan has been keeping silent o\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @Heenaishappy: Prime minister Imran Khan says \u201c#China is the greatest friend of Pakistan\u201d that's why #Pakistan has been keeping silent o\u2026"
# CLEANED TEXT:  prime minister imran khan says china is the greatest friend of pakistan that s why pakistan has been keeping silent o
# CLEANED AND LEMMATIZED:  prime minister imran khan say china is the greatest friend of pakistan that s why pakistan ha been keeping silent o
# SENTIMENT:  positive 🙂 : 🗣 opinion
# LOCATION:  PUNJAB
# Tweet  50 :
#  {
#     "data": {
#         "id": "1407025353198125056",
#         "text": "@kayani_mahrukh Lets just talk about the idea, what @ImranKhanPTI shared, and its 100% according to Al Quran.\nRest the injustice of the society is a separate issue"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "@kayani_mahrukh Lets just talk about the idea, what @ImranKhanPTI shared, and its 100% according to Al Quran.\nRest the injustice of the society is a separate issue"
# CLEANED TEXT:  lets just talk about the idea what shared and its 100 according to al quran rest the injustice of the society is a separate issue
# CLEANED AND LEMMATIZED:  let just talk about the idea what shared and it 100 according to al quran rest the injustice of the society is a separate issue
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  PUNJAB
# Tweet  51 :
#  {
#     "data": {
#         "id": "1407025361708257285",
#         "text": "@Ehtesham70 @ovaismangalwala Bilkul isi trah jis trah aap k walid ne apki walida ko nhi chohra aur phur nikkah krlia isi trah imran Khan ne nikkah krlia bushra bibi se. I hope ab smjh agye hogi."
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "@Ehtesham70 @ovaismangalwala Bilkul isi trah jis trah aap k walid ne apki walida ko nhi chohra aur phur nikkah krlia isi trah imran Khan ne nikkah krlia bushra bibi se. I hope ab smjh agye hogi."
# CLEANED TEXT:  bilkul isi trah jis trah aap k walid ne apki walida ko nhi chohra aur phur nikkah krlia isi trah imran khan ne nikkah krlia bushra bibi se i hope ab smjh agye hogi
# CLEANED AND LEMMATIZED:  bilkul isi trah ji trah aap k walid ne apki walida ko nhi chohra aur phur nikkah krlia isi trah imran khan ne nikkah krlia bushra bibi se i hope ab smjh agye hogi
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  PUNJAB
# Tweet  52 :
#  {
#     "data": {
#         "id": "1407025363507552272",
#         "text": "RT @MeghUpdates: If a Woman wears very Few Clothes, it will have an impact on Men. If you Raise Temptations, Where will Men vent out : Pak\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @MeghUpdates: If a Woman wears very Few Clothes, it will have an impact on Men. If you Raise Temptations, Where will Men vent out : Pak\u2026"
# CLEANED TEXT:  if a woman wears very few clothes it will have an impact on men if you raise temptations where will men vent out pak
# CLEANED AND LEMMATIZED:  if a woman wear very few clothes it will have an impact on men if you raise temptation where will men vent out pak
# SENTIMENT:  negative 😠 : 📊 factual
# LOCATION:  KPK
# Tweet  53 :
#  {
#     "data": {
#         "id": "1407025365021859840",
#         "text": "@Umar_gujjarr ay ma ni keh reya \ud83e\udd2d https://t.co/36n8A2FxDY"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "@Umar_gujjarr ay ma ni keh reya \ud83e\udd2d https://t.co/36n8A2FxDY"
# CLEANED TEXT:  ay ma ni keh reya
# CLEANED AND LEMMATIZED:  ay ma ni keh reya
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  SINDH
# Tweet  54 :
#  {
#     "data": {
#         "id": "1407025367139897344",
#         "text": "@CraigCons If you carry so much pain in your heart about the uyghur Muslims, tell me how many times you have posted about Kashmir that is suffering for decades? People like you and the mainstream media is the hypocrite here."
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "@CraigCons If you carry so much pain in your heart about the uyghur Muslims, tell me how many times you have posted about Kashmir that is suffering for decades? People like you and the mainstream media is the hypocrite here."
# CLEANED TEXT:  if you carry so much pain in your heart about the uyghur muslims tell me how many times you have posted about kashmir that is suffering for decades people like you and the mainstream media is the hypocrite here
# CLEANED AND LEMMATIZED:  if you carry so much pain in your heart about the uyghur muslim tell me how many time you have posted about kashmir that is suffering for decade people like you and the mainstream medium is the hypocrite here
# SENTIMENT:  positive 🙂 : 📊 factual
# LOCATION:  SINDH
# Tweet  55 :
#  {
#     "data": {
#         "id": "1407025379466899456",
#         "text": "Height of hope as @ImranKhanPTI knows he deserves to be on FATF Black list!! https://t.co/Xygi4ErLkJ"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "Height of hope as @ImranKhanPTI knows he deserves to be on FATF Black list!! https://t.co/Xygi4ErLkJ"
# CLEANED TEXT:  height of hope as knows he deserves to be on fatf black list
# CLEANED AND LEMMATIZED:  height of hope a know he deserves to be on fatf black list
# SENTIMENT:  negative 😠 : 📊 factual
# LOCATION:  PUNJAB
# Tweet  56 :
#  {
#     "data": {
#         "id": "1407025386223849472",
#         "text": "RT @C_M_P17: Imran Khan \u0928\u0947 \u0926\u0940 \u092d\u093e\u0930\u0924 \u0915\u094b Nuclear Bomb \u0915\u0940 \u0927\u092e\u0915\u0940, PAK \u0915\u0947 \u090f\u091f\u092e \u092c\u092e \u0915\u0936\u094d\u092e\u0940\u0930 \u0915\u0947 \u0932\u093f\u090f https://t.co/cSAYUZWwU4 via @YouTube"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @C_M_P17: Imran Khan \u0928\u0947 \u0926\u0940 \u092d\u093e\u0930\u0924 \u0915\u094b Nuclear Bomb \u0915\u0940 \u0927\u092e\u0915\u0940, PAK \u0915\u0947 \u090f\u091f\u092e \u092c\u092e \u0915\u0936\u094d\u092e\u0940\u0930 \u0915\u0947 \u0932\u093f\u090f https://t.co/cSAYUZWwU4 via @YouTube"
# CLEANED TEXT:  imran khan nuclear bomb pak via
# CLEANED AND LEMMATIZED:  imran khan nuclear bomb pak via
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  FATA
# Tweet  57 :
#  {
#     "data": {
#         "id": "1407025396604866568",
#         "text": "@FarhanRai02 *sexist!\nAnd he's not!"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "@FarhanRai02 *sexist!\nAnd he's not!"
# CLEANED TEXT:  sexist and he s not
# CLEANED AND LEMMATIZED:  sexist and he s not
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  KPK
# Tweet  58 :
#  {
#     "data": {
#         "id": "1407025397594693632",
#         "text": "@thakur_shivangi Imran khan,Masood Azahar,Hafeez Sayeed and many more are missing in the list."
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "@thakur_shivangi Imran khan,Masood Azahar,Hafeez Sayeed and many more are missing in the list."
# CLEANED TEXT:  imran khan masood azahar hafeez sayeed and many more are missing in the list
# CLEANED AND LEMMATIZED:  imran khan masood azahar hafeez sayeed and many more are missing in the list
# SENTIMENT:  positive 🙂 : 📊 factual
# LOCATION:  PUNJAB
# Tweet  59 :
#  {
#     "data": {
#         "id": "1407025400476274692",
#         "text": "We know its a sin. Wearing short clothes is a sin. No one can justify it. Lets forget about girls wearing short clothes getting raped. What about kids? Boys? Who are being raped? What have they done? Imran khan is completely wrong here. There's no justification. https://t.co/QqeTGWwCkv"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "We know its a sin. Wearing short clothes is a sin. No one can justify it. Lets forget about girls wearing short clothes getting raped. What about kids? Boys? Who are being raped? What have they done? Imran khan is completely wrong here. There's no justification. https://t.co/QqeTGWwCkv"
# ...
#         }
#     ]
# }
# TWEET TEXT:  "RT @sandhu_hamid: Charismatic man of strength, determination, indomitable will, courage, compassion! A man who wrote his own destiny! \nHere\u2026"
# CLEANED TEXT:  charismatic man of strength determination indomitable will courage compassion a man who wrote his own destiny here
# CLEANED AND LEMMATIZED:  charismatic man of strength determination indomitable will courage compassion a man who wrote his own destiny here
# SENTIMENT:  positive 🙂 : 🗣 opinion
# LOCATION:  KPK
# Tweet  252 :
#  {
#     "data": {
#         "id": "1407026268147793927",
#         "text": "RT @anggryagain: Imran khan is absolutely right\n#CancelAllExams #Shafqatmehmood #RapeApologistSelectedPM"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @anggryagain: Imran khan is absolutely right\n#CancelAllExams #Shafqatmehmood #RapeApologistSelectedPM"
# CLEANED TEXT:  imran khan is absolutely rightcancelallexams shafqatmehmood rapeapologistselectedpm
# CLEANED AND LEMMATIZED:  imran khan is absolutely rightcancelallexams shafqatmehmood rapeapologistselectedpm
# SENTIMENT:  positive 🙂 : 🗣 opinion
# LOCATION:  PUNJAB
# Tweet  253 :
#  {
#     "data": {
#         "id": "1407026266855849984",
#         "text": "So disappointed in Imran Khan. I thought he was a good one, obviously better than all those corrupt ones but man, maybe he just cares about success https://t.co/ysGa7FFN1N"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "So disappointed in Imran Khan. I thought he was a good one, obviously better than all those corrupt ones but man, maybe he just cares about success https://t.co/ysGa7FFN1N"
# CLEANED TEXT:  so disappointed in imran khan i thought he was a good one obviously better than all those corrupt ones but man maybe he just cares about success
# CLEANED AND LEMMATIZED:  so disappointed in imran khan i thought he wa a good one obviously better than all those corrupt one but man maybe he just care about success
# SENTIMENT:  positive 🙂 : 🗣 opinion
# LOCATION:  PUNJAB
# Tweet  254 :
#  {
#     "data": {
#         "id": "1407026270198710272",
#         "text": "RT @ShahabSpeaks: 3 unforgettable lines \u2b07\ufe0f\n\nImran Khan: Absolutely Not \nAsif Ghafoor: We will surprise you\nShah Mehmood: Deep pockets"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @ShahabSpeaks: 3 unforgettable lines \u2b07\ufe0f\n\nImran Khan: Absolutely Not \nAsif Ghafoor: We will surprise you\nShah Mehmood: Deep pockets"
# CLEANED TEXT:  3 unforgettable lines imran khan absolutely not asif ghafoor we will surprise youshah mehmood deep pockets
# CLEANED AND LEMMATIZED:  3 unforgettable line imran khan absolutely not asif ghafoor we will surprise youshah mehmood deep pocket
# SENTIMENT:  positive 🙂 : 🗣 opinion
# LOCATION:  PUNJAB
# Tweet  255 :
#  {
#     "data": {
#         "id": "1407026290822057986",
#         "text": "RT @ashoswai: Why does the world expect Imran Khan to raise the Uyghur Muslim issue, but no one asks this to India? What has stopped India\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @ashoswai: Why does the world expect Imran Khan to raise the Uyghur Muslim issue, but no one asks this to India? What has stopped India\u2026"
# CLEANED TEXT:  why does the world expect imran khan to raise the uyghur muslim issue but no one asks this to india what has stopped india
# CLEANED AND LEMMATIZED:  why doe the world expect imran khan to raise the uyghur muslim issue but no one asks this to india what ha stopped india
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:  KPK
# Tweet  256 :
#  {
#     "data": {
#         "id": "1407026296832528384",
#         "text": "RT @AliRazaTweets: Anchor: Does this provoke sexual violence? \nImran Khan:It depends which society you live in. If in a society people have\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @AliRazaTweets: Anchor: Does this provoke sexual violence? \nImran Khan:It depends which society you live in. If in a society people have\u2026"
# CLEANED TEXT:  anchor does this provoke sexual violence imran khan it depends which society you live in if in a society people have
# CLEANED AND LEMMATIZED:  anchor doe this provoke sexual violence imran khan it depends which society you live in if in a society people have
# SENTIMENT:  positive 🙂 : 🗣 opinion
# LOCATION:  PUNJAB
# Tweet  257 :
#  {
#     "data": {
#         "id": "1407026300020273155",
#         "text": "RT @Engr_Naveed111: Anchor: You were accused of rape victim blaming, how do you respond to that ?\n\nHere is complete Answer ..  \n\nListen car\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @Engr_Naveed111: Anchor: You were accused of rape victim blaming, how do you respond to that ?\n\nHere is complete Answer ..  \n\nListen car\u2026"
# CLEANED TEXT:  anchor you were accused of rape victim blaming how do you respond to that here is complete answer listen car
# CLEANED AND LEMMATIZED:  anchor you were accused of rape victim blaming how do you respond to that here is complete answer listen car
# SENTIMENT:  positive 🙂 : 📊 factual
# LOCATION:  KPK
# Tweet  258 :
#  {
#     "data": {
#         "id": "1407026308622675968",
#         "text": "@umerrrkhan_ THIS"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "@umerrrkhan_ THIS"
# CLEANED TEXT:  this
# CLEANED AND LEMMATIZED:  this
# SENTIMENT:  neutral 😶 : 📊 factual
# LOCATION:
u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1407025118488895500,
#             "tag": "politics"
#         }
#     ]
# }
# TWEET TEXT:  "RT @AsYouNotWish: Pakistan\u2019s Prime Minister, Imran Khan defends sexual violence against women again, says men are not robots, women wearing\u2026"
# CLEANED TEXT:  pakistans prime minister imran khan defends sexual violence against women again says men are not robots women wearing
# CLEANED AND LEMMATIZED:  pakistan prime minister imran khan defends sexual violence against woman again say men are not robot woman wearing
# SENTIMENT:  positive 🙂 : 🗣 opinion
# LOCATION:  KPK
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     696         try:
# --> 697             self.chunk_left = int(line, 16)
#     698         except ValueError:
#
# ValueError: invalid literal for int() with base 16: b''
#
# During handling of the above exception, another exception occurred:
#
# InvalidChunkLength                        Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     437             try:
# --> 438                 yield
#     439
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     763             while True:
# --> 764                 self._update_chunk_length()
#     765                 if self.chunk_left == 0:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     700             self.close()
# --> 701             raise InvalidChunkLength(self, line)
#     702
#
# InvalidChunkLength: InvalidChunkLength(got length b'', 0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\models.py in generate()
#     752                 try:
# --> 753                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     754                         yield chunk
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     792             if self._original_response:
# --> 793                 self._original_response.close()
#     794
#
# ~\AppData\Local\Programs\Python\Python39\lib\contextlib.py in __exit__(self, type, value, traceback)
#     134             try:
# --> 135                 self.gen.throw(type, value, traceback)
#     136             except StopIteration as exc:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     454                 # This includes IncompleteRead.
# --> 455                 raise ProtocolError("Connection broken: %r" % e, e)
#     456
#
# ProtocolError: ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
#
# During handling of the above exception, another exception occurred:
#
# ChunkedEncodingError                      Traceback (most recent call last)
# <ipython-input-14-4585b2842158> in <module>
#       8
#       9 if __name__ == "__main__":
# ---> 10     main()
#
# <ipython-input-14-4585b2842158> in main()
#       5     delete = delete_all_rules(headers, bearer_token, rules)
#       6     set = set_rules(headers, delete, bearer_token)
# ----> 7     get_stream(headers, set, bearer_token)
#       8
#       9 if __name__ == "__main__":
#
# <ipython-input-12-0cad656c42ba> in get_stream(headers, set, bearer_token)
#      19     tweetNo = 0
#      20     # Below line gives an error sometimes. This is a twitter API issue being faced by multiple developers and is currently being worked on. SOURCE: https://twittercommunity.com/t/requests-exceptions-chunkedencodingerror/150530 [Accessed: 18 June 2021]
# ---> 21     for response_line in response.iter_lines():
#      22         if response_line:
#      23             tweetNo += 1
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     795         pending = None
#     796
# --> 797         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     798
#     799             if pending is not None:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\models.py in generate()
#     754                         yield chunk
#     755                 except ProtocolError as e:
# --> 756                     raise ChunkedEncodingError(e)
#     757                 except DecodeError as e:
#     758                     raise ContentDecodingError(e)
#
# ChunkedEncodingError: ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))

# %%
# Out:
# 15 15

# %%
# Out:
# 15 15
